# %%
import matplotlib.pyplot as plt
x = [5,2,7]
y = [2,16,4]
plt.plot(x,y)
plt.title('Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
x = [1,2,3,4,5]
y = [50,40,70,80,20]
y2 = [80,20,20,50,60]
y3 = [70,20,60,40,60]
y4 = [80,20,20,50,60]
plt.plot(x,y,'g' , label = 'Enfield', linewidth = 5)
plt.plot(x,y2,'c',label = 'Honda',linewidth = 5)
plt.plot(x,y3,'k',label = 'Yahama', linewidth = 5)
plt.plot(x,y4,'y' , label = 'KTM', linewidth = 5)
plt.title('bike details in line plot')
plt.ylabel('Distance in kms')
plt.xlabel('Days')
plt.legend()

# %%
x_values = [5,6,3,7,2]
y_values = ["A","B","C","D","E"]
plt.bar(y_values, x_values, color = "pink")
plt.show()

# %%
plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],label = "Enfield", width = .5)
plt.bar([0.26,1.25,2.25,3.25,4.25],[80,20,20,50,60],label = "Honda", color = 'r' ,width = .5)
plt.bar([0.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],label = "KTM", color = 'g', width = .5)
plt.bar([0.31,1.5,2.5,3.5,4.5],[70,20,60,40,60],label = "Yamaha", color = 'y', width = .5)
plt.legend()

# %%
# Out:
# ([<matplotlib.patches.Wedge at 0x27f3a80d580>,
# ...
#  [Text(-0.9526279613277876, 0.5499999702695114, 'Enfield'),
#   Text(-0.4592200669382007, -1.108655460511188, 'Honda'),
#   Text(0.8726886847696911, -0.6696375582917575, 'Yahama'),
#   Text(0.7778174593052025, 0.7778174593052022, 'KTM')])

# %%
plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20], label="BMW", color='r')
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60], label="Audi", color='y')
plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.ylabel('Distance (kms)' )
plt.title('Information')
plt.show()

# %%
x_values = [5,6,3,7,2]
y_val = ["A", "B", "C", "D", "E"]
plt.barh(y_val,x_values, color ="yellowgreen")
# Adding an "h" after bar will flip the graph
plt.show()

# %%
x = [5, 2, 9, 4, 7] # x-axis values
y = [10, 5, 8, 4, 2] # Y-axis values
plt.scatter(x, y) # Function to plot scatter
plt.show()

# %%
x = [1,1.5,2,2.5,3,3.5,3.6]
y = [7.5,8,8.5,9,9.5,10,10.5]
x1=[8,8.5,9,9.5,10,10.5,11]
y1=[3,3.5,3.7,4,4.5,5,5.2]
plt.scatter(x,y, label='high income low saving',color='r')
plt.scatter(x1,y1,label='low income high savings',color='b')
plt.xlabel('saving*100')
plt.ylabel('income*1000')
plt.title('Scatter Plot')
plt.legend()
plt.grid()

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
df = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/Deployment-flask/master/hiring.csv')
df
df.test_score = df.test_score.fillna(df.test_score.median())
df
# reg = linear_model.LinearRegression()
# reg.fit(df.drop('price',axis='columns'),df.predict)
# reg.coef_
# reg.intercept_
# reg.predict([[3000, 3, 40]])
# reg.predict([[2500, 4, 5]])
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         8.0                7   72000
# 7     eleven         7.0                8   80000

# %%
plt.xlabel('Days')
plt.ylabel('Distance(in kms)')
                                                                                                                                                                                                                                                                                                                                                                                                                                         
slices = [8,5,5,6];
cols = ['r','g','y','b']
activities = ['Enfield','Honda','Yahama', 'KTM']
plt.pie(slices, labels=activities, colors = cols, startangle = 90, shadow = True, explode = (0,0.1,0,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x27f3c7905e0>,
# ...
#  [Text(-0.9526279613277876, 0.5499999702695114, 'Enfield'),
#   Text(-0.4592200669382007, -1.108655460511188, 'Honda'),
#   Text(0.8726886847696911, -0.6696375582917575, 'Yahama'),
#   Text(0.7778174593052025, 0.7778174593052022, 'KTM')])

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('F:\\machine learning lab\\nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
y_values = df['Salary']
x_values = df['Age']
plt.xlabel('Age')
plt.ylabel('Salary (in millions)')
plt.bar(x_values,y_values,color = "purple")
plt.show()

# %%
y_values = df['Salary']
x_values = df['Age']
plt.xlabel('Age')
plt.ylabel('Salary (in millions)')
plt.barh(x_values,y_values,color = "indianred")
plt.show()

# %%
y_value=df['Salary']
x_values=df['Age']
plt.xlabel('Age')
plt.ylabel('Salary (in millions)')
plt.scatter(x_values,y_values)

# %%
y_value=df['Salary']
x_values=df['Age']
plt.xlabel('Age')
plt.ylabel('Salary (in millions)')
#We can also change the type and colors of scatter plot as shown
plt.scatter(x_values,y_values, color = "slategrey", marker = "x")
